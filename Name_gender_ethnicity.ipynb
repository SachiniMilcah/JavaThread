# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.naive_bayes import MultinomialNB

# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

#authenticate googledrive user
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
downloaded = drive.CreateFile({'id':'1BVHGwJdlLB9Gg4wMZhWzQkjXaUNRL84r'})
downloaded.GetContentFile('gender_ethnicity.csv')

# %%
#load first name dataset 
fname = 'https://raw.githubusercontent.com/philipperemy/name-dataset/master/names_dataset/first_names.all.txt'
name_data = pd.read_csv(fname)
name_data.dropna()
name_data.head()
# Out:
#   --------------------
# 0               a'isha
# 1              a'ishah
# 2                a-jay
# 3              aa'isha
# 4             aa'ishah

# %%
fname_data = name_data.rename(columns = {"--------------------": "NAME" }) 
fname_data.head()
# Out:
#        NAME
# 0    a'isha
# 1   a'ishah
# 2     a-jay
# 3   aa'isha
# 4  aa'ishah

# %%
#load gender and ethnicity dataset
gender_data = pd.read_csv('gender_ethnicity.csv')
pd.set_option('display.max_columns', None)
gender_data.dropna()
gender_data.head()
# Out:
#    BRITH_YEAR  GENDER  ETHNICTY       NAME  COUNT  RANK
# 0        2011  FEMALE  HISPANIC  GERALDINE     13    75
# 1        2011  FEMALE  HISPANIC        GIA     21    67
# 2        2011  FEMALE  HISPANIC     GIANNA     49    42
# 3        2011  FEMALE  HISPANIC    GISELLE     38    51
# 4        2011  FEMALE  HISPANIC      GRACE     36    53

# %%
gender_data2 = gender_data.apply(lambda x: x.astype(str).str.lower())
gender_data2.head()
# Out:
#   BRITH_YEAR  GENDER  ETHNICTY       NAME COUNT RANK
# 0       2011  female  hispanic  geraldine    13   75
# 1       2011  female  hispanic        gia    21   67
# 2       2011  female  hispanic     gianna    49   42
# 3       2011  female  hispanic    giselle    38   51
# 4       2011  female  hispanic      grace    36   53

# %%
#merge first name with gender and ethnicity
mergedData1=fname_data.merge(gender_data2, on='NAME')
mergedData1.head()
# Out:
#       NAME BRITH_YEAR  GENDER                    ETHNICTY COUNT RANK
# 0    aahil       2014    male  asian and pacific islander    14   54
# 1  aaliyah       2011  female          black non hispanic    69    5
# 2  aaliyah       2011  female                    hispanic    63   30
# 3  aaliyah       2011  female          black non hispanic    69    5
# 4  aaliyah       2011  female                    hispanic    63   30

# %%
#load first name, last name dataset
url2 = 'https://media.githubusercontent.com/media/rjurney/baby_names/master/wiki_name_race.csv'
name_data2 = pd.read_csv(url2)
name_data2.head()
# Out:
#                name_last name_suffix        name_first name_middle  \
# 0                 heynis         NaN             aafje         NaN
# 1  noordewier-reddingius         NaN            aaltje         NaN
# 2               de quant         NaN             abbie         NaN
# 3                    NaN         NaN  abbo of provence         NaN
# 4               ahanfouf         NaN         abdelaziz         NaN
#
#                                     race
# 0  GreaterEuropean,WestEuropean,Germanic
# 1  GreaterEuropean,WestEuropean,Germanic
# 2  GreaterEuropean,WestEuropean,Germanic
# 3  GreaterEuropean,WestEuropean,Germanic
# 4  GreaterEuropean,WestEuropean,Germanic

# %%
lname_data1 = name_data2.rename(columns = {"name_first": "NAME" }) 
lname_data1.head()
# Out:
#                name_last name_suffix              NAME name_middle  \
# 0                 heynis         NaN             aafje         NaN
# 1  noordewier-reddingius         NaN            aaltje         NaN
# 2               de quant         NaN             abbie         NaN
# 3                    NaN         NaN  abbo of provence         NaN
# 4               ahanfouf         NaN         abdelaziz         NaN
#
#                                     race
# 0  GreaterEuropean,WestEuropean,Germanic
# 1  GreaterEuropean,WestEuropean,Germanic
# 2  GreaterEuropean,WestEuropean,Germanic
# 3  GreaterEuropean,WestEuropean,Germanic
# 4  GreaterEuropean,WestEuropean,Germanic

# %%
#merge first name with last name
mergedData2=mergedData1.merge(lname_data1, on='NAME')
mergedData2.head()
# Out:
#     NAME BRITH_YEAR GENDER                    ETHNICTY COUNT RANK  \
# 0  aaron       2011   male  asian and pacific islander    51   19
# 1  aaron       2011   male  asian and pacific islander    51   19
# 2  aaron       2011   male  asian and pacific islander    51   19
# 3  aaron       2011   male  asian and pacific islander    51   19
# 4  aaron       2011   male  asian and pacific islander    51   19
#
#      name_last name_suffix name_middle                                   race
# 0      abraham         NaN         NaN  GreaterEuropean,WestEuropean,Hispanic
# 1  schwartzman         NaN         NaN  GreaterEuropean,WestEuropean,Hispanic
# 2          NaN         NaN         NaN                 GreaterEuropean,Jewish
# 3    aaronsohn         NaN         NaN                 GreaterEuropean,Jewish
# 4    alexandre         NaN         NaN                 GreaterEuropean,Jewish

# %%
count_row = mergedData2.shape[0] 
print(count_row)
# Out:
# 929750

# %%
alldata = mergedData2.rename(columns = {"NAME": "First_Name" , "name_last": "Last_Name" ,"GENDER": "Inferred_Gender","ETHNICTY": "Inferred_Ethnicity"}) 
alldata = alldata.drop(columns = ['BRITH_YEAR', 'COUNT','RANK','name_suffix','name_middle','race'], axis=1)
alldata.head(100)
# Out:
#    First_Name Inferred_Gender          Inferred_Ethnicity    Last_Name
# 0       aaron            male  asian and pacific islander      abraham
# 1       aaron            male  asian and pacific islander  schwartzman
# 2       aaron            male  asian and pacific islander          NaN
# 3       aaron            male  asian and pacific islander    aaronsohn
# 4       aaron            male  asian and pacific islander    alexandre
# ..        ...             ...                         ...          ...
# 95      aaron            male          black non hispanic         hart
# 96      aaron            male          black non hispanic  ibn sargado
# 97      aaron            male          black non hispanic        isaac
# 98      aaron            male          black non hispanic       kernis
# 99      aaron            male          black non hispanic    karfunkel
#
# [100 rows x 4 columns]

# %%
#get full name using first name and last name
alldata["Full_Name"] = (alldata["First_Name"] +" "+ alldata["Last_Name"])
alldata.head()
# Out:
#   First_Name Inferred_Gender          Inferred_Ethnicity    Last_Name  \
# 0      aaron            male  asian and pacific islander      abraham
# 1      aaron            male  asian and pacific islander  schwartzman
# 2      aaron            male  asian and pacific islander          NaN
# 3      aaron            male  asian and pacific islander    aaronsohn
# 4      aaron            male  asian and pacific islander    alexandre
#
#            Full_Name
# 0      aaron abraham
# 1  aaron schwartzman
# 2                NaN
# 3    aaron aaronsohn
# 4    aaron alexandre

# %%
#drop null values
data = alldata.dropna()

# %%
count_row = data.shape[0] 
print(count_row)
# Out:
# 922779

# %%
# Replacing Female and Male with 0 and 1
data.Inferred_Gender.replace({'female':0,'male':1},inplace=True)
data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#   First_Name  Inferred_Gender          Inferred_Ethnicity    Last_Name  \
# 0      aaron                1  asian and pacific islander      abraham
# 1      aaron                1  asian and pacific islander  schwartzman
# 3      aaron                1  asian and pacific islander    aaronsohn
# 4      aaron                1  asian and pacific islander    alexandre
# 5      aaron                1  asian and pacific islander         adan
#
#            Full_Name
# 0      aaron abraham
# 1  aaron schwartzman
# 3    aaron aaronsohn
# 4    aaron alexandre
# 5         aaron adan

# %%
#feature data
X = data['Full_Name']

# %%
#vectorize feature
vector1 = TfidfVectorizer()
X = vector1.fit_transform(X)

# %%
vector1.get_feature_names()
# Out:
# ['1765',
#  '1837',
#  'aabye',
#  'aaes',
#  'aamer',
#  'aaron',
#  'aaronovitch',
#  'aaronsohn',
#  'aasen',
#  'abacco',
#  'abacha',
#  'abaco',
#  'abada',
#  'abadie',
#  'aballay',
#  'abalo',
#  'abancour',
#  'abarca',
#  'abaroa',
#  'abart',
#  'abatantuono',
#  'abate',
#  'abba',
#  'abbadie',
#  'abbado',
#  'abbamonte',
#  'abbandando',
#  'abbandante',
#  'abbar',
#  'abbas',
#  'abbasi',
#  'abbate',
#  'abbatemarco',
#  'abbatessa',
#  'abbati',
#  'abbaticchio',
#  'abbatini',
#  'abbensetts',
#  'abberley',
#  'abbey',
#  'abbiati',
#  'abbington',
#  'abbondanzieri',
#  'abbot',
#  'abbott',
#  'abbotts',
#  'abboud',
#  'abbruscato',
#  'abby',
#  'abd',
#  'abdala',
#  'abdallah',
#  'abdellaoui',
#  'abdi',
#  'abdillat',
#  'abdou',
#  'abdoulahi',
#  'abdoulaye',
#  'abdul',
#  'abdulaziz',
#  'abdulkhaleq',
#  'abdulla',
#  'abdullah',
#  'abdullahi',
#  'abdy',
#  'abecassis',
#  'abeel',
#  'abeijón',
#  'abeille',
#  'abel',
#  'abelard',
#  'abeles',
#  'abelin',
#  'abell',
#  'abella',
#  'abelli',
#  'abellio',
#  'abelly',
#  'abendana',
#  'abenhaim',
#  'abercrombie',
#  'abercromby',
#  'abergavenny',
#  'abern',
#  'abernethy',
#  'abershawe',
#  'abert',
#  'abescat',
#  'abess',
#  'abetz',
#  'abeyie',
#  'abhayavardhana',
#  'abi',
#  'abicht',
#  'abid',
#  'abigail',
#  'abigdor',
#  'abin',
#  'abineri',
#  'abington',
#  'abish',
#  'abitbol',
#  'abkarian',
#  'abkoude',
#  'ablanedo',
#  'able',
#  'ableman',
#  'ablesimov',
#  'abney',
#  'abo',
#  'aboab',
#  'aborah',
#  'aboud',
#  'abourezk',
#  'aboutaleb',
#  'abouzeid',
#  'abrabanel',
#  'abraham',
#  'abrahams',
#  'abram',
#  'abramo',
#  'abramoff',
#  'abramov',
#  'abramovich',
#  'abramovitz',
#  'abramowicz',
#  'abramowitz',
#  'abrams',
#  'abramsky',
#  'abramson',
#  'abrashkin',
#  'abravanel',
#  'abreu',
#  'abrial',
#  'abrunhosa',
#  'abruzzese',
#  'abruzzi',
#  'abruzzo',
#  'absalon',
#  'abse',
#  'absolom',
#  'absolon',
#  'abu',
#  'abubakari',
#  'abud',
#  'abudraham',
#  'abuelo',
#  'abukasis',
#  'abul',
#  'abulafia',
#  'abumohor',
#  'abunimah',
#  'abunnadi',
#  'aburrow',
#  'abushwesha',
#  'abzug',
#  'acasiete',
#  'accardo',
#  'accarigi',
#  'accatino',
#  'accetturo',
#  'accolti',
#  'accursi',
#  'acda',
#  'acerbi',
#  'aceval',
#  'acevedo',
#  'acfield',
#  'achaari',
#  'achard',
#  'acheampong',
#  'achille',
#  'achilleos',
#  'achleitner',
#  'achron',
#  'achterfeldt',
#  'achtschelling',
#  'achu',
#  'achúgar',
#  'acioly',
#  'acker',
#  'ackerman',
#  'ackery',
#  'ackford',
#  'ackland',
#  'ackman',
#  'ackner',
#  'ackroyd',
#  'acland',
#  'acontius',
#  'acorah',
#  'acosta',
#  'acqua',
#  'acquafresca',
#  'acra',
#  'acte',
#  'acton',
#  'acuña',
#  'acworth',
#  'ad',
#  'ada',
#  'adaf',
#  'adaggio',
#  'adair',
#  'adajania',
#  'adam',
#  'adamo',
#  'adamov',
#  'adamovsky',
#  'adams',
#  'adamson',
#  'adamthwaite',
#  'adan',
#  'adar',
#  'adarbi',
#  'adaskin',
#  'adat',
#  'adayevskaya',
#  'adcock',
#  'adda',
#  'addabbo',
#  'addams',
#  'addenbrooke',
#  'addey',
#  'addie',
#  'addington',
#  'addinsell',
#  'addio',
#  'addis',
#  'addison',
#  'addo',
#  'addou',
#  'addy',
#  'addyman',
#  'ade',
#  'adeane',
#  'adebayor',
#  'adebisi',
#  'adekunle',
#  'adelaide',
#  'adele',
#  'adeleke',
#  'adelin',
#  'adelina',
#  'adeline',
#  'adelstein',
#  'adelung',
#  'ademeno',
#  'ademolu',
#  'aden',
#  'adeney',
#  'adeni',
#  'aderet',
#  'adeyanju',
#  'adhemar',
#  'adie',
#  'adil',
#  'adina',
#  'aditya',
#  'adjani',
#  'adjaye',
#  'adjetey',
#  'adlam',
#  'adler',
#  'adley',
#  'adlington',
#  'adnan',
#  'adolf',
#  'adolphus',
#  'adonai',
#  'adonis',
#  'adorf',
#  'adorno',
#  'adrian',
#  'adriana',
#  'adriani',
#  'adrianna',
#  'adriel',
#  'adrisi',
#  'adrogué',
#  'adrover',
#  'adshead',
#  'adson',
#  'adu',
#  'adua',
#  'advani',
#  'advis',
#  'adwani',
#  'adye',
#  'adyebo',
#  'adão',
#  'aetheling',
#  'afandi',
#  'afendopolo',
#  'aferi',
#  'affleck',
#  'afford',
#  'afinogenov',
#  'afonso',
#  'africanus',
#  'afriyie',
#  'aftalion',
#  'afzal',
#  'aga',
#  'agali',
#  'agamennoni',
#  'agana',
#  'agar',
#  'agard',
#  'agarde',
#  'agarwal',
#  'agassi',
#  'agata',
#  'agate',
#  'agayants',
#  'agbonlahor',
#  'ageeb',
#  'agello',
#  'ageno',
#  'agg',
#  'agger',
#  'aggett',
#  'aggrey',
#  'aggudey',
#  'aghahowa',
#  'aghatise',
#  'agius',
#  'aglaé',
#  'agliardi',
#  'aglietta',
#  'aglionby',
#  'agmon',
#  'agnelli',
#  'agnello',
#  'agnew',
#  'ago',
#  'agocchie',
#  'agodino',
#  'agosti',
#  'agostini',
#  'agostino',
#  'agosto',
#  'agote',
#  'agreda',
#  'agresti',
#  'agricola',
#  'agrios',
#  'agrippa',
#  'agronsky',
#  'agrote',
#  'agu',
#  'agucchi',
#  'aguiar',
#  'aguilar',
#  'aguilera',
#  'aguilé',
#  'aguinaga',
#  'aguinaldo',
#  'aguinis',
#  'aguirre',
#  'aguirregaray',
#  'agurbash',
#  'agyemang',
#  'agüero',
#  'aharon',
#  'ahdout',
#  'ahl',
#  'ahlers',
#  'ahlstrand',
#  'ahmad',
#  'ahmed',
#  'ahn',
#  'ahron',
#  'ahuja',
#  'ahumada',
#  'ai',
#  'aib',
#  'aiblinger',
#  'aicard',
#  'aicardi',
#  'aickman',
#  'aida',
#  'aidaeva',
#  'aidala',
#  'aidan',
#  'aiden',
#  'aidoo',
#  'aiello',
#  'aigalliers',
#  'aiken',
#  'aikenhead',
#  'aikhenvald',
#  'aikin',
#  'aileen',
#  'ailey',
#  'aimar',
#  'aimee',
#  'aimson',
#  'ainger',
#  'ainley',
#  'ainscough',
#  'ainsley',
#  'ainsworth',
#  'aird',
#  'airmine',
#  'airosa',
#  'airport',
#  'aisha',
#  'aislabie',
#  'aiston',
#  'aita',
#  'aitchison',
#  'aitken',
#  'aitkenhead',
#  'aitkens',
#  'aitova',
#  'aiuppa',
#  'aiyubi',
#  'aizlewood',
#  'ajayi',
#  'ajiba',
#  'akabya',
#  'akaka',
#  'akakia',
#  'akandu',
#  'akavia',
#  'akbar',
#  'akbulut',
#  'akchaoui',
#  'akdemir',
#  'akenside',
#  'akerlof',
#  'akerman',
#  'akers',
#  'akhmatova',
#  'akhsharumova',
#  'akhtar',
#  'akhwari',
#  'aki',
#  'akimov',
#  'akinloye',
#  'akinluyi',
#  'akinola',
#  'akins',
#  'akintola',
#  'akinwande',
#  'akinyele',
#  'akitani',
#  'akiva',
#  'akiyama',
#  'akkari',
#  'akobiya',
#  'akonnor',
#  'akpala',
#  'akpoborie',
#  'akra',
#  'aksakov',
#  'aksentsev',
#  'akst',
#  'aku',
#  'akuffo',
#  'akufo',
#  'akume',
#  'akumfi',
#  'akwari',
#  'akyol',
#  'al',
#  'ala',
#  'alabardi',
#  'alabaster',
#  'alagiah',
#  'alagna',
#  'alain',
#  'alaine',
#  'alami',
#  'alamo',
#  'alamos',
#  'alan',
#  'alana',
#  'alapin',
#  'alarcón',
#  'alarza',
#  'alashkar',
#  'alatas',
#  'alazraki',
#  'alba',
#  'albalag',
#  'albanel',
#  'albani',
#  'albano',
#  'albar',
#  'albarello',
#  'albargeloni',
#  'albarn',
#  'albarracín',
#  'albelda',
#  'alberdi',
#  'alberstein',
#  'albert',
#  'alberti',
#  'alberto',
#  'albertsen',
#  'albery',
#  'albicastro',
#  'albicocco',
#  'albidani',
#  'albini',
#  'albizuri',
#  'albo',
#  'albon',
#  'alborough',
#  'albou',
#  'albrecht',
#  'albrechtsen',
#  'albret',
#  'albright',
#  'albu',
#  'albuquerque',
#  'alburt',
#  'alcala',
#  'alcantara',
#  'alcazar',
#  'alciati',
#  'alciato',
#  'alcock',
#  'alcoforado',
#  'alcott',
#  'alcubierre',
#  'alcón',
#  'aldecoa',
#  'alder',
#  'alderisio',
#  'alderman',
#  'aldersey',
#  'alderson',
#  'alderton',
#  'aldini',
#  'aldo',
#  'aldous',
#  'aldred',
#  'aldrich',
#  'aldridge',
#  'aldwinckle',
#  'aldworth',
#  'alec',
#  'aleccio',
#  'alegre',
#  'alegria',
#  'alegría',
#  'aleixo',
#  'alejandra',
#  'alejandro',
#  'alekhine',
#  'aleksander',
#  'aleksandra',
#  'alekseev',
#  'alekseyev',
#  'alekseyevna',
#  'alele',
#  'alem',
#  'alema',
#  'aleman',
#  'alembert',
#  'alemán',
#  'alencastre',
#  'alende',
#  'alençon',
#  'aleotti',
#  'alerte',
#  'alesandro',
#  'alesi',
#  'alessandra',
#  'alessandri',
#  'alessandro',
#  'alessi',
#  'alessia',
#  'alex',
#  'alexa',
#  'alexander',
#  'alexandra',
#  'alexandre',
#  'alexandrou',
#  'alexandrov',
#  'alexandrovich',
#  'alexandrovna',
#  'alexeev',
#  'alexeievna',
#  'alexia',
#  'alexis',
#  'aleyn',
#  'alfa',
#  'alfandari',
#  'alfano',
#  'alfaro',
#  'alfasi',
#  'alflen',
#  'alfonse',
#  'alfonzo',
#  'alford',
#  'alfred',
#  'alfredo',
#  'algarotti',
#  'algazi',
#  'algerino',
#  'algren',
#  'alharizi',
#  'alhassan',
#  'alhazred',
#  'alhusseini',
#  'ali',
#  'aliaj',
#  'aliberti',
#  'alice',
#  'alicia',
#  'alidosi',
#  'alier',
#  'alighieri',
#  'alikhan',
#  'alim',
#  'alina',
#  'alinei',
#  'alington',
#  'alinsky',
#  'alioto',
#  'alioui',
#  'alisa',
#  'alisha',
#  'alison',
#  'alito',
#  'aliyah',
#  'aliza',
#  'alkabetz',
#  'alkalai',
#  'alken',
#  'alkorta',
#  'allain',
#  'allais',
#  'allam',
#  'allan',
#  'allanson',
#  'allard',
#  'allason',
#  'allaun',
#  'allawi',
#  'allberry',
#  'allbritton',
#  'allbrook',
#  'allbutt',
#  'allcock',
#  'allcott',
#  'allcroft',
#  'allde',
#  'alldis',
#  'alldritt',
#  'allegra',
#  'allegrain',
#  'allegro',
#  'alleine',
#  'allemand',
#  'allen',
#  'allende',
#  'allender',
#  'allensworth',
#  'allers',
#  'allerton',
#  'allestree',
#  'alley',
#  'alleyn',
#  'alleyne',
#  'alli',
#  'alliance',
#  'allibone',
#  'allies',
#  'allievi',
#  'allingham',
#  'allington',
#  'allinson',
#  'allio',
#  'allison',
#  'alliss',
#  'allmark',
#  'allnatt',
#  'allom',
#  'allon',
#  'allone',
#  'allotey',
#  'allott',
#  'allport',
#  'allsburg',
#  'allsopp',
#  'alluaud',
#  'allucingoli',
#  'ally',
#  'allyson',
#  'allégret',
#  'alma',
#  'almagro',
#  'almalki',
#  'almandoz',
#  'almeida',
#  'almenas',
#  'almirón',
#  'almodóvar',
#  'almogi',
#  'almoli',
#  'almond',
#  'almosnino',
#  'almoznino',
#  'alms',
#  'almuzahim',
#  'alnoudji',
#  'alnwick',
#  'alo',
#  'aloi',
#  'aloisi',
#  'alon',
#  'aloni',
#  'alonso',
#  'alonzo',
#  'alopaeus',
#  'alpass',
#  'alperstein',
#  'alquinta',
#  'alroy',
#  'alsabti',
#  'alschuler',
#  'alsford',
#  'alsgaard',
#  'alshich',
#  'alsloot',
#  'alsop',
#  'alston',
#  'alsultany',
#  'altamira',
#  'altamirano',
#  'altamont',
#  'altenburg',
#  'alter',
#  'alterio',
#  'altgeld',
#  'altham',
#  'althusser',
#  'altias',
#  'altman',
#  'altmann',
#  'alton',
#  'altschul',
#  'altä',
#  'aluma',
#  'alva',
#  'alvanis',
#  'alvarado',
#  'alvarez',
#  'alvaro',
#  'alvars',
#  'alvary',
#  'alvear',
#  'alvel',
#  'alverdes',
#  'alves',
#  'alvheim',
#  'alvim',
#  'alvin',
#  'alway',
#  'alwis',
#  'alwyn',
#  'alyabyev',
#  'alyngton',
#  'alypov',
#  'alyson',
#  'alyssa',
#  'alzaga',
#  'alzamendi',
#  'alzey',
#  'alzog',
#  'am',
#  'ama',
#  'amadei',
#  'amadeus',
#  'amado',
#  'amador',
#  'amadori',
#  'amadou',
#  'amaechi',
#  'amalfi',
#  'amalia',
#  'amalie',
#  'amanda',
#  'amanfoh',
#  'amani',
#  'amankwaah',
#  'amar',
#  'amara',
#  'amaral',
#  'amarel',
#  'amastan',
#  'amat',
#  'amateau',
#  'amati',
#  'amato',
#  'amaya',
#  'ambar',
#  'ambekar',
#  'amber',
#  'amberg',
#  'ambler',
#  'ambree',
#  'ambrogio',
#  'ambrose',
#  'ambrosi',
#  'ambrosini',
#  'ambrosio',
#  'amdurski',
#  'ameche',
#  'amedokpo',
#  'amelchenko',
#  'amelia',
#  'amelie',
#  'amelino',
#  'amendola',
#  'amenábar',
#  'amerike',
#  'amery',
#  'ames',
#  'amess',
#  'ameyaw',
#  'amherst',
#  'amhurst',
#  'ami',
#  'amias',
#  'amichai',
#  'amici',
#  'amico',
#  'amidei',
#  'amiel',
#  'amies',
#  'amighetti',
#  'amigo',
#  'amigorena',
#  'amike',
#  'amin',
#  'amina',
#  'aminata',
#  'amiot',
#  'amir',
#  'amira',
#  'amirajibi',
#  'amiri',
#  'amis',
#  'amiss',
#  'amissah',
#  'amit',
#  'amital',
#  'amitrano',
#  'amiya',
#  'ammar',
#  'ammerbach',
#  'ammi',
#  'ammonio',
#  'amo',
#  'amoah',
#  'amoateng',
#  'amonte',
#  'amoo',
#  'amore',
#  'amorebieta',
#  'amorim',
#  'amoros',
#  'amorosi',
#  'amory',
#  'amos',
#  'amoudi',
#  'amour',
#  'amparo',
#  'amroliwala',
#  'amrouche',
#  'amstell',
#  'amu',
#  'amundsen',
#  'amuneke',
#  'amuso',
#  'amwell',
#  'amy',
#  'amyn',
#  'américo',
#  'an',
#  'ana',
#  'anais',
#  'anam',
#  'anan',
#  'anand',
#  'ananda',
#  'anantharaman',
#  'ananya',
#  'anapoli',
#  'anast',
#  'anastasi',
#  'anastasia',
#  'anastasio',
#  'anastasiu',
#  'anatole',
#  'anatuppi',
#  'anaw',
#  'anaya',
#  'ancher',
#  'anchia',
#  'anciano',
#  'ancillon',
#  'anckarström',
#  'ancona',
#  'ancram',
#  'ancízar',
#  'and',
#  'anda',
#  'ander',
#  'anders',
#  'andersch',
#  'andersen',
#  'anderson',
#  'andersson',
#  'anderton',
#  'andie',
#  'andjaba',
#  'ando',
#  'andrada',
#  'andrade',
#  'andre',
#  'andrea',
#  'andreacchio',
#  'andreani',
#  'andreas',
#  'andreasen',
#  'andreatti',
#  'andreev',
#  'andreoli',
#  'andreolli',
#  'andres',
#  'andresen',
#  'andretti',
#  'andreu',
#  'andrew',
#  'andrews',
#  'andria',
#  'andriamanjato',
#  'andrisani',
#  'andrus',
#  'andré',
#  'andrés',
#  'andy',
#  'anelay',
#  'anelka',
#  'anerio',
#  'anesi',
#  'anfuso',
#  'angarrack',
#  'angel',
#  'angela',
#  'angelelli',
#  'angeleri',
#  'angeles',
#  'angeli',
#  'angelica',
#  'angelillo',
#  'angelina',
#  'angelique',
#  'angelis',
#  'angell',
#  'angelo',
#  'angeloni',
#  'angeloz',
#  'angelsen',
#  'angennes',
#  'anger',
#  'angers',
#  'angerstein',
#  'anghelides',
#  'angie',
#  'anglade',
#  'angloma',
#  'ango',
#  'angold',
#  'angoulvant',
#  'angoulême',
#  'angueira',
#  'anguish',
#  'angulo',
#  'angus',
#  'angélique',
#  'angély',
#  'anichebe',
#  'anionwu',
#  'anisa',
#  'anisimova',
#  'anissina',
#  'anjos',
#  'anjou',
#  'anjum',
#  'anka',
#  'anker',
#  'anna',
#  ...]

# %%
from sklearn.model_selection import train_test_split

#label
y = data['Inferred_Gender']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# classification using Naive Bayes Classifier
clf = MultinomialNB()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.9939576642431646

# %%
#predict gender using input name
def predict_gender(name):
    test_name = [name]
    gen = vector1.transform(test_name).toarray()
    if clf.predict(gen) == 0:
        gend = 'Female'
        return gend
        
    else:
        gend = 'Male'
        return gend

# %%
data['Inferred_Ethnicity'].unique()
# Out:
# array(['asian and pacific islander', 'black non hispanic', 'hispanic',
#        'white non hispanic', 'asian and paci', 'black non hisp',
#        'white non hisp'], dtype=object)

# %%
class_names = ['asian and pacific islander', 'black non hispanic', 'hispanic',
       'white non hispanic', 'asian and paci', 'black non hisp',
       'white non hisp']

# %%
len(class_names)
# Out:
# 7

# %%
# Features
Xfeatures = data['Full_Name']
#label
ylabels= data['Inferred_Ethnicity']

# %%
# Vectorize Features
vector = TfidfVectorizer()
X = vector.fit_transform(Xfeatures)

# %%
vector.get_feature_names()
# Out:
# ['1765',
#  '1837',
#  'aabye',
#  'aaes',
#  'aamer',
#  'aaron',
#  'aaronovitch',
#  'aaronsohn',
#  'aasen',
#  'abacco',
#  'abacha',
#  'abaco',
#  'abada',
#  'abadie',
#  'aballay',
#  'abalo',
#  'abancour',
#  'abarca',
#  'abaroa',
#  'abart',
#  'abatantuono',
#  'abate',
#  'abba',
#  'abbadie',
#  'abbado',
#  'abbamonte',
#  'abbandando',
#  'abbandante',
#  'abbar',
#  'abbas',
#  'abbasi',
#  'abbate',
#  'abbatemarco',
#  'abbatessa',
#  'abbati',
#  'abbaticchio',
#  'abbatini',
#  'abbensetts',
#  'abberley',
#  'abbey',
#  'abbiati',
#  'abbington',
#  'abbondanzieri',
#  'abbot',
#  'abbott',
#  'abbotts',
#  'abboud',
#  'abbruscato',
#  'abby',
#  'abd',
#  'abdala',
#  'abdallah',
#  'abdellaoui',
#  'abdi',
#  'abdillat',
#  'abdou',
#  'abdoulahi',
#  'abdoulaye',
#  'abdul',
#  'abdulaziz',
#  'abdulkhaleq',
#  'abdulla',
#  'abdullah',
#  'abdullahi',
#  'abdy',
#  'abecassis',
#  'abeel',
#  'abeijón',
#  'abeille',
#  'abel',
#  'abelard',
#  'abeles',
#  'abelin',
#  'abell',
#  'abella',
#  'abelli',
#  'abellio',
#  'abelly',
#  'abendana',
#  'abenhaim',
#  'abercrombie',
#  'abercromby',
#  'abergavenny',
#  'abern',
#  'abernethy',
#  'abershawe',
#  'abert',
#  'abescat',
#  'abess',
#  'abetz',
#  'abeyie',
#  'abhayavardhana',
#  'abi',
#  'abicht',
#  'abid',
#  'abigail',
#  'abigdor',
#  'abin',
#  'abineri',
#  'abington',
#  'abish',
#  'abitbol',
#  'abkarian',
#  'abkoude',
#  'ablanedo',
#  'able',
#  'ableman',
#  'ablesimov',
#  'abney',
#  'abo',
#  'aboab',
#  'aborah',
#  'aboud',
#  'abourezk',
#  'aboutaleb',
#  'abouzeid',
#  'abrabanel',
#  'abraham',
#  'abrahams',
#  'abram',
#  'abramo',
#  'abramoff',
#  'abramov',
#  'abramovich',
#  'abramovitz',
#  'abramowicz',
#  'abramowitz',
#  'abrams',
#  'abramsky',
#  'abramson',
#  'abrashkin',
#  'abravanel',
#  'abreu',
#  'abrial',
#  'abrunhosa',
#  'abruzzese',
#  'abruzzi',
#  'abruzzo',
#  'absalon',
#  'abse',
#  'absolom',
#  'absolon',
#  'abu',
#  'abubakari',
#  'abud',
#  'abudraham',
#  'abuelo',
#  'abukasis',
#  'abul',
#  'abulafia',
#  'abumohor',
#  'abunimah',
#  'abunnadi',
#  'aburrow',
#  'abushwesha',
#  'abzug',
#  'acasiete',
#  'accardo',
#  'accarigi',
#  'accatino',
#  'accetturo',
#  'accolti',
#  'accursi',
#  'acda',
#  'acerbi',
#  'aceval',
#  'acevedo',
#  'acfield',
#  'achaari',
#  'achard',
#  'acheampong',
#  'achille',
#  'achilleos',
#  'achleitner',
#  'achron',
#  'achterfeldt',
#  'achtschelling',
#  'achu',
#  'achúgar',
#  'acioly',
#  'acker',
#  'ackerman',
#  'ackery',
#  'ackford',
#  'ackland',
#  'ackman',
#  'ackner',
#  'ackroyd',
#  'acland',
#  'acontius',
#  'acorah',
#  'acosta',
#  'acqua',
#  'acquafresca',
#  'acra',
#  'acte',
#  'acton',
#  'acuña',
#  'acworth',
#  'ad',
#  'ada',
#  'adaf',
#  'adaggio',
#  'adair',
#  'adajania',
#  'adam',
#  'adamo',
#  'adamov',
#  'adamovsky',
#  'adams',
#  'adamson',
#  'adamthwaite',
#  'adan',
#  'adar',
#  'adarbi',
#  'adaskin',
#  'adat',
#  'adayevskaya',
#  'adcock',
#  'adda',
#  'addabbo',
#  'addams',
#  'addenbrooke',
#  'addey',
#  'addie',
#  'addington',
#  'addinsell',
#  'addio',
#  'addis',
#  'addison',
#  'addo',
#  'addou',
#  'addy',
#  'addyman',
#  'ade',
#  'adeane',
#  'adebayor',
#  'adebisi',
#  'adekunle',
#  'adelaide',
#  'adele',
#  'adeleke',
#  'adelin',
#  'adelina',
#  'adeline',
#  'adelstein',
#  'adelung',
#  'ademeno',
#  'ademolu',
#  'aden',
#  'adeney',
#  'adeni',
#  'aderet',
#  'adeyanju',
#  'adhemar',
#  'adie',
#  'adil',
#  'adina',
#  'aditya',
#  'adjani',
#  'adjaye',
#  'adjetey',
#  'adlam',
#  'adler',
#  'adley',
#  'adlington',
#  'adnan',
#  'adolf',
#  'adolphus',
#  'adonai',
#  'adonis',
#  'adorf',
#  'adorno',
#  'adrian',
#  'adriana',
#  'adriani',
#  'adrianna',
#  'adriel',
#  'adrisi',
#  'adrogué',
#  'adrover',
#  'adshead',
#  'adson',
#  'adu',
#  'adua',
#  'advani',
#  'advis',
#  'adwani',
#  'adye',
#  'adyebo',
#  'adão',
#  'aetheling',
#  'afandi',
#  'afendopolo',
#  'aferi',
#  'affleck',
#  'afford',
#  'afinogenov',
#  'afonso',
#  'africanus',
#  'afriyie',
#  'aftalion',
#  'afzal',
#  'aga',
#  'agali',
#  'agamennoni',
#  'agana',
#  'agar',
#  'agard',
#  'agarde',
#  'agarwal',
#  'agassi',
#  'agata',
#  'agate',
#  'agayants',
#  'agbonlahor',
#  'ageeb',
#  'agello',
#  'ageno',
#  'agg',
#  'agger',
#  'aggett',
#  'aggrey',
#  'aggudey',
#  'aghahowa',
#  'aghatise',
#  'agius',
#  'aglaé',
#  'agliardi',
#  'aglietta',
#  'aglionby',
#  'agmon',
#  'agnelli',
#  'agnello',
#  'agnew',
#  'ago',
#  'agocchie',
#  'agodino',
#  'agosti',
#  'agostini',
#  'agostino',
#  'agosto',
#  'agote',
#  'agreda',
#  'agresti',
#  'agricola',
#  'agrios',
#  'agrippa',
#  'agronsky',
#  'agrote',
#  'agu',
#  'agucchi',
#  'aguiar',
#  'aguilar',
#  'aguilera',
#  'aguilé',
#  'aguinaga',
#  'aguinaldo',
#  'aguinis',
#  'aguirre',
#  'aguirregaray',
#  'agurbash',
#  'agyemang',
#  'agüero',
#  'aharon',
#  'ahdout',
#  'ahl',
#  'ahlers',
#  'ahlstrand',
#  'ahmad',
#  'ahmed',
#  'ahn',
#  'ahron',
#  'ahuja',
#  'ahumada',
#  'ai',
#  'aib',
#  'aiblinger',
#  'aicard',
#  'aicardi',
#  'aickman',
#  'aida',
#  'aidaeva',
#  'aidala',
#  'aidan',
#  'aiden',
#  'aidoo',
#  'aiello',
#  'aigalliers',
#  'aiken',
#  'aikenhead',
#  'aikhenvald',
#  'aikin',
#  'aileen',
#  'ailey',
#  'aimar',
#  'aimee',
#  'aimson',
#  'ainger',
#  'ainley',
#  'ainscough',
#  'ainsley',
#  'ainsworth',
#  'aird',
#  'airmine',
#  'airosa',
#  'airport',
#  'aisha',
#  'aislabie',
#  'aiston',
#  'aita',
#  'aitchison',
#  'aitken',
#  'aitkenhead',
#  'aitkens',
#  'aitova',
#  'aiuppa',
#  'aiyubi',
#  'aizlewood',
#  'ajayi',
#  'ajiba',
#  'akabya',
#  'akaka',
#  'akakia',
#  'akandu',
#  'akavia',
#  'akbar',
#  'akbulut',
#  'akchaoui',
#  'akdemir',
#  'akenside',
#  'akerlof',
#  'akerman',
#  'akers',
#  'akhmatova',
#  'akhsharumova',
#  'akhtar',
#  'akhwari',
#  'aki',
#  'akimov',
#  'akinloye',
#  'akinluyi',
#  'akinola',
#  'akins',
#  'akintola',
#  'akinwande',
#  'akinyele',
#  'akitani',
#  'akiva',
#  'akiyama',
#  'akkari',
#  'akobiya',
#  'akonnor',
#  'akpala',
#  'akpoborie',
#  'akra',
#  'aksakov',
#  'aksentsev',
#  'akst',
#  'aku',
#  'akuffo',
#  'akufo',
#  'akume',
#  'akumfi',
#  'akwari',
#  'akyol',
#  'al',
#  'ala',
#  'alabardi',
#  'alabaster',
#  'alagiah',
#  'alagna',
#  'alain',
#  'alaine',
#  'alami',
#  'alamo',
#  'alamos',
#  'alan',
#  'alana',
#  'alapin',
#  'alarcón',
#  'alarza',
#  'alashkar',
#  'alatas',
#  'alazraki',
#  'alba',
#  'albalag',
#  'albanel',
#  'albani',
#  'albano',
#  'albar',
#  'albarello',
#  'albargeloni',
#  'albarn',
#  'albarracín',
#  'albelda',
#  'alberdi',
#  'alberstein',
#  'albert',
#  'alberti',
#  'alberto',
#  'albertsen',
#  'albery',
#  'albicastro',
#  'albicocco',
#  'albidani',
#  'albini',
#  'albizuri',
#  'albo',
#  'albon',
#  'alborough',
#  'albou',
#  'albrecht',
#  'albrechtsen',
#  'albret',
#  'albright',
#  'albu',
#  'albuquerque',
#  'alburt',
#  'alcala',
#  'alcantara',
#  'alcazar',
#  'alciati',
#  'alciato',
#  'alcock',
#  'alcoforado',
#  'alcott',
#  'alcubierre',
#  'alcón',
#  'aldecoa',
#  'alder',
#  'alderisio',
#  'alderman',
#  'aldersey',
#  'alderson',
#  'alderton',
#  'aldini',
#  'aldo',
#  'aldous',
#  'aldred',
#  'aldrich',
#  'aldridge',
#  'aldwinckle',
#  'aldworth',
#  'alec',
#  'aleccio',
#  'alegre',
#  'alegria',
#  'alegría',
#  'aleixo',
#  'alejandra',
#  'alejandro',
#  'alekhine',
#  'aleksander',
#  'aleksandra',
#  'alekseev',
#  'alekseyev',
#  'alekseyevna',
#  'alele',
#  'alem',
#  'alema',
#  'aleman',
#  'alembert',
#  'alemán',
#  'alencastre',
#  'alende',
#  'alençon',
#  'aleotti',
#  'alerte',
#  'alesandro',
#  'alesi',
#  'alessandra',
#  'alessandri',
#  'alessandro',
#  'alessi',
#  'alessia',
#  'alex',
#  'alexa',
#  'alexander',
#  'alexandra',
#  'alexandre',
#  'alexandrou',
#  'alexandrov',
#  'alexandrovich',
#  'alexandrovna',
#  'alexeev',
#  'alexeievna',
#  'alexia',
#  'alexis',
#  'aleyn',
#  'alfa',
#  'alfandari',
#  'alfano',
#  'alfaro',
#  'alfasi',
#  'alflen',
#  'alfonse',
#  'alfonzo',
#  'alford',
#  'alfred',
#  'alfredo',
#  'algarotti',
#  'algazi',
#  'algerino',
#  'algren',
#  'alharizi',
#  'alhassan',
#  'alhazred',
#  'alhusseini',
#  'ali',
#  'aliaj',
#  'aliberti',
#  'alice',
#  'alicia',
#  'alidosi',
#  'alier',
#  'alighieri',
#  'alikhan',
#  'alim',
#  'alina',
#  'alinei',
#  'alington',
#  'alinsky',
#  'alioto',
#  'alioui',
#  'alisa',
#  'alisha',
#  'alison',
#  'alito',
#  'aliyah',
#  'aliza',
#  'alkabetz',
#  'alkalai',
#  'alken',
#  'alkorta',
#  'allain',
#  'allais',
#  'allam',
#  'allan',
#  'allanson',
#  'allard',
#  'allason',
#  'allaun',
#  'allawi',
#  'allberry',
#  'allbritton',
#  'allbrook',
#  'allbutt',
#  'allcock',
#  'allcott',
#  'allcroft',
#  'allde',
#  'alldis',
#  'alldritt',
#  'allegra',
#  'allegrain',
#  'allegro',
#  'alleine',
#  'allemand',
#  'allen',
#  'allende',
#  'allender',
#  'allensworth',
#  'allers',
#  'allerton',
#  'allestree',
#  'alley',
#  'alleyn',
#  'alleyne',
#  'alli',
#  'alliance',
#  'allibone',
#  'allies',
#  'allievi',
#  'allingham',
#  'allington',
#  'allinson',
#  'allio',
#  'allison',
#  'alliss',
#  'allmark',
#  'allnatt',
#  'allom',
#  'allon',
#  'allone',
#  'allotey',
#  'allott',
#  'allport',
#  'allsburg',
#  'allsopp',
#  'alluaud',
#  'allucingoli',
#  'ally',
#  'allyson',
#  'allégret',
#  'alma',
#  'almagro',
#  'almalki',
#  'almandoz',
#  'almeida',
#  'almenas',
#  'almirón',
#  'almodóvar',
#  'almogi',
#  'almoli',
#  'almond',
#  'almosnino',
#  'almoznino',
#  'alms',
#  'almuzahim',
#  'alnoudji',
#  'alnwick',
#  'alo',
#  'aloi',
#  'aloisi',
#  'alon',
#  'aloni',
#  'alonso',
#  'alonzo',
#  'alopaeus',
#  'alpass',
#  'alperstein',
#  'alquinta',
#  'alroy',
#  'alsabti',
#  'alschuler',
#  'alsford',
#  'alsgaard',
#  'alshich',
#  'alsloot',
#  'alsop',
#  'alston',
#  'alsultany',
#  'altamira',
#  'altamirano',
#  'altamont',
#  'altenburg',
#  'alter',
#  'alterio',
#  'altgeld',
#  'altham',
#  'althusser',
#  'altias',
#  'altman',
#  'altmann',
#  'alton',
#  'altschul',
#  'altä',
#  'aluma',
#  'alva',
#  'alvanis',
#  'alvarado',
#  'alvarez',
#  'alvaro',
#  'alvars',
#  'alvary',
#  'alvear',
#  'alvel',
#  'alverdes',
#  'alves',
#  'alvheim',
#  'alvim',
#  'alvin',
#  'alway',
#  'alwis',
#  'alwyn',
#  'alyabyev',
#  'alyngton',
#  'alypov',
#  'alyson',
#  'alyssa',
#  'alzaga',
#  'alzamendi',
#  'alzey',
#  'alzog',
#  'am',
#  'ama',
#  'amadei',
#  'amadeus',
#  'amado',
#  'amador',
#  'amadori',
#  'amadou',
#  'amaechi',
#  'amalfi',
#  'amalia',
#  'amalie',
#  'amanda',
#  'amanfoh',
#  'amani',
#  'amankwaah',
#  'amar',
#  'amara',
#  'amaral',
#  'amarel',
#  'amastan',
#  'amat',
#  'amateau',
#  'amati',
#  'amato',
#  'amaya',
#  'ambar',
#  'ambekar',
#  'amber',
#  'amberg',
#  'ambler',
#  'ambree',
#  'ambrogio',
#  'ambrose',
#  'ambrosi',
#  'ambrosini',
#  'ambrosio',
#  'amdurski',
#  'ameche',
#  'amedokpo',
#  'amelchenko',
#  'amelia',
#  'amelie',
#  'amelino',
#  'amendola',
#  'amenábar',
#  'amerike',
#  'amery',
#  'ames',
#  'amess',
#  'ameyaw',
#  'amherst',
#  'amhurst',
#  'ami',
#  'amias',
#  'amichai',
#  'amici',
#  'amico',
#  'amidei',
#  'amiel',
#  'amies',
#  'amighetti',
#  'amigo',
#  'amigorena',
#  'amike',
#  'amin',
#  'amina',
#  'aminata',
#  'amiot',
#  'amir',
#  'amira',
#  'amirajibi',
#  'amiri',
#  'amis',
#  'amiss',
#  'amissah',
#  'amit',
#  'amital',
#  'amitrano',
#  'amiya',
#  'ammar',
#  'ammerbach',
#  'ammi',
#  'ammonio',
#  'amo',
#  'amoah',
#  'amoateng',
#  'amonte',
#  'amoo',
#  'amore',
#  'amorebieta',
#  'amorim',
#  'amoros',
#  'amorosi',
#  'amory',
#  'amos',
#  'amoudi',
#  'amour',
#  'amparo',
#  'amroliwala',
#  'amrouche',
#  'amstell',
#  'amu',
#  'amundsen',
#  'amuneke',
#  'amuso',
#  'amwell',
#  'amy',
#  'amyn',
#  'américo',
#  'an',
#  'ana',
#  'anais',
#  'anam',
#  'anan',
#  'anand',
#  'ananda',
#  'anantharaman',
#  'ananya',
#  'anapoli',
#  'anast',
#  'anastasi',
#  'anastasia',
#  'anastasio',
#  'anastasiu',
#  'anatole',
#  'anatuppi',
#  'anaw',
#  'anaya',
#  'ancher',
#  'anchia',
#  'anciano',
#  'ancillon',
#  'anckarström',
#  'ancona',
#  'ancram',
#  'ancízar',
#  'and',
#  'anda',
#  'ander',
#  'anders',
#  'andersch',
#  'andersen',
#  'anderson',
#  'andersson',
#  'anderton',
#  'andie',
#  'andjaba',
#  'ando',
#  'andrada',
#  'andrade',
#  'andre',
#  'andrea',
#  'andreacchio',
#  'andreani',
#  'andreas',
#  'andreasen',
#  'andreatti',
#  'andreev',
#  'andreoli',
#  'andreolli',
#  'andres',
#  'andresen',
#  'andretti',
#  'andreu',
#  'andrew',
#  'andrews',
#  'andria',
#  'andriamanjato',
#  'andrisani',
#  'andrus',
#  'andré',
#  'andrés',
#  'andy',
#  'anelay',
#  'anelka',
#  'anerio',
#  'anesi',
#  'anfuso',
#  'angarrack',
#  'angel',
#  'angela',
#  'angelelli',
#  'angeleri',
#  'angeles',
#  'angeli',
#  'angelica',
#  'angelillo',
#  'angelina',
#  'angelique',
#  'angelis',
#  'angell',
#  'angelo',
#  'angeloni',
#  'angeloz',
#  'angelsen',
#  'angennes',
#  'anger',
#  'angers',
#  'angerstein',
#  'anghelides',
#  'angie',
#  'anglade',
#  'angloma',
#  'ango',
#  'angold',
#  'angoulvant',
#  'angoulême',
#  'angueira',
#  'anguish',
#  'angulo',
#  'angus',
#  'angélique',
#  'angély',
#  'anichebe',
#  'anionwu',
#  'anisa',
#  'anisimova',
#  'anissina',
#  'anjos',
#  'anjou',
#  'anjum',
#  'anka',
#  'anker',
#  'anna',
#  ...]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,ylabels,test_size=0.33,random_state=42)

# %%
# classification using Naive Bayes Classifier
naiv = MultinomialNB()
naiv.fit(x_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
f_name = input('Enter First Name :')
# Out:
# Enter First Name :mary

# %%
l_name = input('Enter Last Name :')
# Out:
# Enter Last Name :priya

# %%
name = (f_name + ' ' + l_name)

# %%
name_eth= ['name']
predict_eth = vector.transform(name_eth).toarray()

# %%
ethnic = naiv.predict(predict_eth)

# %%
inf_gender = predict_gender(name)

# %%
print('First Name :',f_name ,'\nLast Name :', l_name, '\nInferred Gender :', inf_gender,'\nInferred Ethnicity :', ethnic[0] )
# Out:
# First Name : mary
# Last Name : priya
# Inferred Gender : Female
# Inferred Ethnicity : hispanic
